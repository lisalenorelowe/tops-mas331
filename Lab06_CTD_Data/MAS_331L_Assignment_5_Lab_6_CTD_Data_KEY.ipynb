# %% [markdown]
# # <center> Lab 6: Plotting and Analyzing CTD Data </center>

# %% [markdown]
# ---
# Welcome to the Python component of Lab 5! Since we went out in the boat and have collected a transect of data, we are going to actually analyze our own data!
#
# We will go through some more plotting and manipulation of the data we actually collected.
#
# Just as before, we would like you to download your work as both an html and ipynb file and **save a figure of your choice** to Canvas.

# %% [markdown]
# ---
# #### Please acknowledge that you understand the instructions by copying and pasting each of the following into the next cells.
#
# #I understand how to save my progress and reopen the notebook.
#
# #I understand that I am being asked to save and submit copies of my notebook as well as a figure of my choice for the assignment.
#
# #I understand that I need to comment my code.

# %%
#I understand how to save my progress and reopen the notebook.

# %%
#I understand that I am being asked to save and submit copies of my notebook as well as a figure of my choice for the assignment.

# %%
#I understand that I need to comment my code.

# %% [markdown]
# ## Let's get started!
#
# First, import a couple packages that we will use throughout this assignment

# %%
#Import Pandas and alias it as 'pd'
#for manipulating tables and timeseries
import pandas as pd

#Import MatPlotLib and alias it as 'plt'
#for making plots/graphs/figures
import matplotlib.pyplot as plt

#Import Numpy and alias it as 'np'
#for the arrays
import numpy as np

# %% [markdown]
# ### Read in data

# %%
#Start by reading in the data files
#We'll help with by loading station 4
#Keeping the variable names consisten with our recommendations will help later in the assignment

filename4 = "station4_CTD0_092422.xls" # name it filename4 for station 4, filename1 for station 1, etc.
df_4 = pd.read_excel(filename4) # name it df_4 for station 4, df_1 for station 1, etc.

# %%
# peek at the data
df_4.head()
# Out:
#    Scan  Depth  Salinity    TempC  O2Percent      O2     pH   SpecCond  \
# 0   762  0.210   30.3975  29.3154     90.585  5.8584  7.838  46785.747
# 1   763  0.229   30.3968  29.3156     90.557  5.8566  7.838  46784.719
# 2   764  0.248   30.3971  29.3150     90.618  5.8606  7.838  46785.242
# 3   765  0.267   30.3965  29.3160     90.687  5.8650  7.838  46784.381
# 4   766  0.362   30.3959  29.3164     90.764  5.8700  7.838  46783.569
#
#    BeamAtt  BeamTrans    Density   Cond           PAR  FlCDOM  FlWETSTAR
# 0   2.2075    80.1916  1018.5096  50830  1.000000e-12  1.5341          0
# 1   2.2075    80.1916  1018.5091  50829  1.000000e-12  1.5341          0
# 2   2.2075    80.1916  1018.5096  50829  1.000000e-12  1.5341          0
# 3   2.2075    80.1916  1018.5089  50829  1.000000e-12  1.5341          0
# 4   2.2205    80.0875  1018.5087  50829  1.000000e-12  1.5341          0

# %% [markdown]
# Now it's your turn! Read in the remaining data files, take a peek at the data, and answer the questions from Exercise 1.

# %%
#create filename variables for each station
filename1 = "station1_CTD3_092422.xls"
filename2 = "station2_CTD2_092422.xls" 
filename3 = "station3_CTD1_092422.xls"
filename4 = "station4_CTD0_092422.xls"
#read in dataframes for each file
df_1 = pd.read_excel(filename1)
df_2 = pd.read_excel(filename2)
df_3 = pd.read_excel(filename3)
df_4 = pd.read_excel(filename4)

# %%
df_2.head() #take a peak
# Out:
#    Scan  Depth  Salinity    TempC  O2Percent      O2     pH   SpecCond  \
# 0   519  0.286   29.0752  29.7003     91.843  5.9461  7.837  44965.597
# 1   520  0.305   29.0784  29.7019     91.811  5.9437  7.837  44969.959
# 2   521  0.324   29.0758  29.6993     91.749  5.9400  7.837  44966.414
# 3   522  0.362   29.0716  29.6973     91.742  5.9399  7.837  44960.619
# 4   523  0.419   29.0639  29.6887     91.797  5.9445  7.819  44949.904
#
#    BeamAtt  BeamTrans    Density   Cond           PAR  FlCDOM  FlWETSTAR
# 0   1.0249    90.2588  1017.3931  49199  1.000000e-12  1.7783          0
# 1   1.0249    90.2588  1017.3949  49205  1.000000e-12  1.7783          0
# 2   1.0249    90.2588  1017.3940  49199  1.000000e-12  1.7783          0
# 3   1.0249    90.2588  1017.3917  49191  1.000000e-12  1.7783          0
# 4   1.0364    90.1547  1017.3890  49171  1.000000e-12  1.7783          0

# %%
df_3.head() #take a peak
# Out:
#    Scan  Depth  Salinity    TempC  O2Percent      O2     pH   SpecCond  \
# 0   452  0.438   30.0998  29.4830     89.726  5.7966  7.851  46377.608
# 1   453  0.457   30.1012  29.4842     89.837  5.8036  7.851  46379.541
# 2   454  0.476   30.1013  29.4847     89.898  5.8075  7.851  46379.588
# 3   455  0.495   30.1060  29.4800     89.962  5.8120  7.846  46386.151
# 4   456  0.552   30.1043  29.4786     89.977  5.8131  7.851  46383.757
#
#    BeamAtt  BeamTrans    Density   Cond           PAR  FlCDOM  FlWETSTAR
# 0   0.5658     94.499  1018.2322  50542  1.000000e-12  0.1300          0
# 1   0.5631     94.525  1018.2330  50546  1.000000e-12  0.0995          0
# 2   0.5631     94.525  1018.2329  50546  1.000000e-12  0.1300          0
# 3   0.5658     94.499  1018.2381  50549  1.000000e-12  0.0079          0
# 4   6.5306     52.045  1018.2376  50545  1.000000e-12  0.1300          0

# %%
df_4.head() #take a peak
# Out:
#    Scan  Depth  Salinity    TempC  O2Percent      O2     pH   SpecCond  \
# 0   762  0.210   30.3975  29.3154     90.585  5.8584  7.838  46785.747
# 1   763  0.229   30.3968  29.3156     90.557  5.8566  7.838  46784.719
# 2   764  0.248   30.3971  29.3150     90.618  5.8606  7.838  46785.242
# 3   765  0.267   30.3965  29.3160     90.687  5.8650  7.838  46784.381
# 4   766  0.362   30.3959  29.3164     90.764  5.8700  7.838  46783.569
#
#    BeamAtt  BeamTrans    Density   Cond           PAR  FlCDOM  FlWETSTAR
# 0   2.2075    80.1916  1018.5096  50830  1.000000e-12  1.5341          0
# 1   2.2075    80.1916  1018.5091  50829  1.000000e-12  1.5341          0
# 2   2.2075    80.1916  1018.5096  50829  1.000000e-12  1.5341          0
# 3   2.2075    80.1916  1018.5089  50829  1.000000e-12  1.5341          0
# 4   2.2205    80.0875  1018.5087  50829  1.000000e-12  1.5341          0

# %% [markdown]
# ### Exercise 1: Answer some Qs about the data
#
# 1. How does the CTD calculate depth?
#
# 2. How does it measure salinity?
#
# 3. What is the importance of O2 measurements? What are some possible sources and sinks of oxygen in the water column?

# %% [markdown]
# My answers:
#
# 1. It calculates depth based on the pressure reading. 1m is apporximately 1dbar in pressure.
# 2. It uses the conductivity of the water as well as the depth and temperature data.
# 3. Oxygen greatly influences the chemical and biological environment. It is a requirement for respiration and breaks down organic material as it sinks through the water column. Photosynthesis and diffusion from the atmosphere are major sources; sinks are processes such as organic matter degradation and respiration, as mentioned.

# %% [markdown]
# 4. Look at the headings of the columns. Make a table in markdown showing the abbreviation (in the raw data), measured variable, and unit for *any five variables*. See the syntax for a table in the next cell.

# %% [markdown]
# | Heading1 | Heading2 | Heading3 |
# | :-: | :-: | :-: |
# | cellinfo1 | cellinfo2 | cellinfo3 |

# %% [markdown]
# This is the corresponding code; do not execute this cell
#
# | Heading1 | Heading2 | Heading3 | #You can have as many rows as you'd like, but each must be bookended by vertical lines
# | :-: | :-: | :-: | #This line aligns the cells in the middle
# | cellinfo1 | cellinfo2 | cellinfo3 | #Repeat this line for as many additional rows as you'd like

# %% [markdown]
# Make the table below. Keep the cell in markdown mode.

# %% [markdown]
# | Table Reading | Measured Variable | Unit |
# | :-: | :-: | :-: |
# | Depth | depth | m |
# | Salinity | salnity | ppt |
# | TempC | temperature | degrees Celsius |
# | O2 | oxygen concentration | mg/L |
# | pH | pH | unitless |

# %% [markdown]
# ---
# # Vertical Profiles

# %%
#Let's start with the temperature at station 1

fig1, (ax1) = plt.subplots() # There's only 1 plot, so subplot argument is empty
ax1.plot(df_4["TempC"],df_4["Depth"])

# Draw x label
ax1.set_xlabel('Temperature (C)')
ax1.xaxis.set_label_position('top') # this moves the label to the top
ax1.xaxis.set_ticks_position('top') # this moves the ticks to the top

# Draw y label
ax1.set_ylabel('Depth (m)')
ax1.set_ylim(ax1.get_ylim()[::-1]) #this reverses the yaxis (i.e. deep at the bottom)
# Out:
# (20.4435, -0.7535000000000001)

# %% [markdown]
# ### Add another CTD profile to the plot
#
# Let's add another variable to the graph to see two CTD profiles plotted together.
#
# We can plot a second variable with temperature by creating another axis using
# ax2 = ax.twiny()
#
# By default, ax1 will be on the bottom, and ax2 will be on the top. Because we want temperature displayed on the top, we will call it ax2. We no longer need the command moving the x-axis and tick marks for temperature to the top of the graph.
#
# Let's add a plot of DO on ax1.

# %%
#plot DO and temp profiles
fig1, (ax1) = plt.subplots() # There's only 1 plot, so subplot argument is empty

ax1.plot(df_4["O2"],df_4["Depth"]) #plot DO
ax1.set_xlabel('DO (mg/l)')
ax1.set_ylabel('Depth (m)')
ax1.set_ylim(ax1.get_ylim()[::-1]) #this reverses the yaxis (i.e. deep at the bottom)

ax2 = ax1.twiny() #plot a second variable
ax2.plot(df_4["TempC"],df_4["Depth"]) # plot temp
ax2.set_xlabel('Temperature (°C)')
# Out:
# Text(0.5, 0, 'Temperature (°C)')

# %% [markdown]
# Ok this looks pretty good except we can't tell which line is which variable.
# Let's change the colors for each variable and axis, so we can easily read the plot.
# Let's take a look at the base colors available for matplotlib.
#
# | Syntax | Color |
# | :-: | :-: |
# | 'b' | blue |
# | 'g' | green |
# | 'r' | red |
# | 'c' | cyan |
# | 'm' | magenta |
# | 'y' | yellow |
# | 'k' | black |
# | 'w' | white |
#
# There are a lot more colors available, but these are your basic choices.

# %% [markdown]
# Now we can use these commands to change the colors of the plot
#
# | Syntax | Effect |
# | :-: | :-: |
# | ax.xaxis.label.set_color('y') | Set X-axis label color |
# | ax.tick_params(axis='x', colors='y') | Set X-axis tick color |
# | ax.spines['top'].set_color('y') | Set top spine color |
#
# Let's start with DO.

# %%
#plot DO and temp profiles
fig1, (ax1) = plt.subplots() # <-- only 1 plot, so subplot argument is empty
ax1.plot(df_4["O2"],df_4["Depth"], "g") #plot DO in green
ax1.set_xlabel('DO (mg/l)')
ax1.set_ylabel('Depth (m)')
ax1.set_ylim(ax1.get_ylim()[::-1]) #this reverses the yaxis (i.e. deep at the bottom)
ax1.xaxis.label.set_color('g') #setting up X-axis label color to green
ax1.tick_params(axis='x', colors='g') #setting up X-axis tick color to green
ax1.spines['bottom'].set_color('g') #setting up bottom spine as green

ax2 = ax1.twiny()
ax2.plot(df_4["TempC"],df_4["Depth"]) # plot temp
ax2.set_xlabel('Temperature (°C)')
# Out:
# Text(0.5, 0, 'Temperature (°C)')

# %% [markdown]
# ### Exercise 2
#
# Recreate the plot above, but make the below changes:
#
# Change the xticks, xlabel, xspine, and x values for temp to all the same color.
# You can keep it as the default blue or select another color.

# %%
#plot DO and temp profiles
fig1, (ax1) = plt.subplots() # <-- only 1 plot, so subplot argument is empty
ax1.plot(df_4["O2"],df_4["Depth"], "g") #plot DO in green
ax1.set_xlabel('DO (mg/l)')
ax1.set_ylabel('Depth (m)')
ax1.set_ylim(ax1.get_ylim()[::-1]) #this reverses the yaxis (i.e. deep at the bottom)
ax1.xaxis.label.set_color('g') #setting up X-axis label color to green
ax1.tick_params(axis='x', colors='g') #setting up X-axis tick color to green
ax1.spines['bottom'].set_color('g') #setting up bottom spine as green

ax2 = ax1.twiny()
ax2.plot(df_4["TempC"],df_4["Depth"],'b') # plot temp
ax2.set_xlabel('Temperature (°C)')
ax2.xaxis.label.set_color('b') #setting up X-axis label color to blue
ax2.tick_params(axis='x', colors='b') #setting up X-axis tick color to blue
ax2.spines['top'].set_color('b') #setting up top spine as blue

# %% [markdown]
# ---
# # Vertical Profile Subplots
#
# Instead of graphing the CTD profiles for variables on the same graph, let's try doing subplots. Sometimes a single graph for multiple variables is too messy, and having subplots can display the information more clearly.
#
# We'll start with our original plot for temp, then add a plot next to it for salinity

# %%
# Create subplots of temp and salinity

#subplot now has ax1 and ax2
#Subplot arguments are (1, 2, sharey = True)
#(1,2) makes 1 row and 2 columns of subplots
#sharey = true allows them to share y-axes with the same scaling and scale labels.
fig1, (ax1, ax2) = plt.subplots(1,2,sharey=True)

# Temperature
ax1.plot(df_4["TempC"],df_4["Depth"]) # plot
ax1.set_xlabel('Temperature (°C)') # x axis
ax1.xaxis.set_label_position('top') 
ax1.xaxis.set_ticks_position('top') 
ax1.set_ylim(ax1.get_ylim()[::-1])
ax1.set_ylabel('Depth (m)') # y axis

# Salinity
ax2.plot(df_4["Salinity"],df_4["Depth"], 'r') # plot
ax2.set_xlabel('Salinity (psu)') # x axis
ax2.xaxis.set_label_position('top') 
ax2.xaxis.set_ticks_position('top') 
ax2.set_ylabel('Depth (m)') # y axis
fig1.suptitle("Station 4, Sep 24, 2022") #gives a grand title that covers all subplots
# Out:
# Text(0.5, 0.98, 'Station 4, Sep 24, 2022')

# %% [markdown]
# How does the title look to you?
# We need to move it in order to read it!
#
# ### Exercise 3
#
# Add x and y coordinates to move the grand title up using:
#
# fig1.suptitle("Station 1, Sep 24, 2022", x= , y= )
#
# Try your own values for x and y until you find ones that make sense.
#
# Let's also get rid of the ylabel for the 2nd plot since we don't really need it.

# %%
# Create subplots of temp and salinity

#subplot now has ax1 and ax2
#Subplot arguments are (1, 2, sharey = True)
#(1,2) makes 1 row and 2 columns of subplots
#sharey = true allows them to share y-axes with the same scaling and scale labels.
fig1, (ax1, ax2) = plt.subplots(1,2,sharey=True)

# Temperature
ax1.plot(df_4["TempC"],df_4["Depth"]) # plot
ax1.set_xlabel('Temperature (°C)') # x axis
ax1.xaxis.set_label_position('top') 
ax1.xaxis.set_ticks_position('top') 
ax1.set_ylim(ax1.get_ylim()[::-1])
ax1.set_ylabel('Depth (m)') # y axis

# Salinity
ax2.plot(df_4["Salinity"],df_4["Depth"], 'r') # plot
ax2.set_xlabel('Salinity (psu)') # x axis
ax2.xaxis.set_label_position('top') 
ax2.xaxis.set_ticks_position('top') 
fig1.suptitle("Station 4, Sep 24, 2022", x=0.5, y=1.1) #gives a grand title that covers all subplots
# Out:
# Text(0.5, 1.1, 'Station 4, Sep 24, 2022')

# %% [markdown]
# ### Exercise 4:
#
# Add 2 more subplots of the variable of your choosing. Make each variable a different color or style of line.
#
# Put the new plots next to the first two.

# %%
#subplot now has several ax arguments
#Subplot arguments are (1, 5, sharey = True)
#(1,5) makes 1 row and 5 columns of subplots
#I am doing an extra plot; the assignment only calls for 4
#sharey = true allows them to share y-axes with the same scaling and scale labels.
fig1, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(1,5,sharey=True)
#yours should say
#fig1, (ax1, ax2, ax3, ax4)=plt.subplots(1,4,sharey=true)

# Temperature
ax1.plot(df_4["TempC"],df_4["Depth"]) # plot
ax1.set_xlabel('Temperature (°C)') # x axis
ax1.xaxis.set_label_position('top') 
ax1.xaxis.set_ticks_position('top') 
ax1.set_ylim(ax1.get_ylim()[::-1])
ax1.set_ylabel('Depth (m)') # y axis

# Salinity
ax2.plot(df_4["Salinity"],df_4["Depth"], 'r') # plot
ax2.set_xlabel('Salinity (psu)') # x axis
ax2.xaxis.set_label_position('top') 
ax2.xaxis.set_ticks_position('top') 

#DO
ax3.plot(df_4["O2"],df_4["Depth"], "g") #plot DO in green
ax3.set_xlabel('DO (mg/L)') # x axis
ax3.xaxis.set_label_position('top') 
ax3.xaxis.set_ticks_position('top') 

#pH
ax4.plot(df_4["pH"],df_4["Depth"], "y") #plot pH in yellow
ax4.set_xlabel('pH') # x axis
ax4.xaxis.set_label_position('top') 
ax4.xaxis.set_ticks_position('top') 

#Density 
#adding for fun and to see potential water masses
#you did not need a fifth plot per the assignment
ax5.plot(df_4["Density"],df_4["Depth"], "k") #plot density in black
ax5.set_xlabel('Density (g/L)') # x axis
ax5.xaxis.set_label_position('top') 
ax5.xaxis.set_ticks_position('top') 



#this should be after everything else
fig1.suptitle("Station 4, Sep 24, 2022", x=0.5, y=1.1) #gives a grand title that covers all subplots
# Out:
# Text(0.5, 1.1, 'Station 4, Sep 24, 2022')

# %% [markdown]
# ### Exercise 5: Answer the Questions Below
#
# Look at the variables you plotted.
#
# 1. Describe the characteristics of each vertical profile. What, if any, are the differences between the surface, middle, and bottom water?
#
# 2. How many layers of water masses are indicated from the vertical profiles?
#
# 3. Under what conditions would you expect to see the values for a given variable to be the same at the surface and bottom? If surface and bottom values were the same for salinity, would you expect them to be the same for other variables too?
#
# 4. What variable do you think is driving the differences between the water column layers?

# %% [markdown]
# #### Possible Answers:
#
# 1. Temperature is lower in the surface, increases just above 5m, and then decreases again. However the differences are less than a degree. Salinity is lowest at the surface, increases around 5m, and is max at depth. DO is high and steady for 7.5m before decreasing to the bottom. pH swings back and forth on a small scale, with no real pattern.
#
# 2. There seems to be a surface layer in the top 5m, followed by the pycnocline into the bottom water mass. So, two full water masses.
#
# 3. I would expect the variables to be the same at the surface and bottom when the entire water column is well mized. If they were the same for salinity, I would expect there to be little variation in the other variables as well.
#
# 4. I think salinity is driving the difference. There is little variation in the temperature (<1degC), and the salinity profile matches that of the density profile.

# %% [markdown]
# ---
# # Vertical profiles of our Transect
# This transect runs from inshore (station 1) to offshore (station 4).

# %% [markdown]
# Let's plot a 2D contour map of a variable across the transect.
#
# This will be similar to the colormap we made in the Lab 3 of Python Intro I

# %% [markdown]
# First we have to read in our location data and make corresponding arrays. Since this is a North to South transect, we will deal with latitude only. Not all cruise tracks will be mostly in a straight line; often you will have to deal with both longitude and latitude.

# %%
#Ensure that you have uploaded all your data files.

filename5 = "Lab6_lat.xlsx"
df_lat = pd.read_excel(filename5)

# %%
print(df_lat)
# Out:
#    Station       Lat
# 0        1  30.29000
# 1        2  30.42750
# 2        3  30.21056
# 3        4  30.16694

# %% [markdown]
# Our goal is graph each variable using depth as the x axis, latitude as the y axis, and z, or the contour, as the CTD variable we are interested in. We can also think of the y axis as the station locations, just represented by their latitude.
#
# First we need to create an array of each latitude for each station.
#
# Let's start with the station 4, the most offshore station.

# %%
#how long of a latitude array do we need?
#pick any variable in MB and check its size

df_4["TempC"].size
# Out:
# 316

# %%
#We need to make a 316x1 array for latitude at station MB
#Populate the array with the lat for the station.

lat_4 = np.full((316,1), 30.16694)
print(lat_4)
# Out:
# [[30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]]

# %% [markdown]
# Looks good. Now we need to do the same thing for the rest of the stations.

# %% [markdown]
# ### Exercise 6
#
# Create latitude arrays for stations 1, 2, and 3.

# %%
#setting the lat3 array to the size of the temp data, as above
#and adding in the actual lat of the station
lat_3 = np.full((df_3["TempC"].size,1), 30.21056)

# %%
df_3['TempC'].size
# Out:
# 190

# %%
df_2['TempC'].size
# Out:
# 103

# %%
df_1['TempC'].size
# Out:
# 237

# %%
#for the remaining arrays
lat_2 = np.full((df_2["TempC"].size,1), 30.42750)
lat_1 = np.full((df_1["TempC"].size,1), 30.29000)

# %% [markdown]
# Great! Now we have all the latitude arrays.
#
# If we want to plot the CTD profile of a variable across an entire transect, we need to combine the data from each station. We use concatenate commands to do this. Concatenation basically just means "combining".
#
# Let's start by doing that for the latitudes arrays that we just created. We can combine them using
#
# np.concatenate([array1, array2, etc.])

# %%
# combine the lat arrays

lat_all = np.concatenate([lat_1, lat_2, lat_3, lat_4]) #fill in the arguments for each array as defined above
print(lat_all)
# Out:
# [[30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.29   ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.4275 ]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.21056]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]
#  [30.16694]]

# %% [markdown]
# Great. Now let's combine all our depths from each station.
# We must concatenate in the same order as we did for the latitudes, so that all the values match up.
#
# Since our depths are in a dataframe, we will use pd.concat() instead of np.concatenate()

# %%
# vert cat depths
#make sure the dataframe names match yours.
#make sure that the station order is the same as when we combined the lat arrays
depth_all = pd.concat([df_1["Depth"],df_2["Depth"], df_3["Depth"], df_4["Depth"]])
print(depth_all)
# Out:
# 0       0.495
# 1       0.495
# 2       0.533
# 3       0.590
# 4       0.667
#         ...
# 311    19.442
# 312    19.442
# 313    19.442
# 314    19.461
# 315    19.480
# Name: Depth, Length: 846, dtype: float64

# %% [markdown]
# ### Exercise 7
#
# Pick a CTD variable that you want to plot across the transect.
#
# Using pd.concat(), concatenate that variable just like you did for depth.

# %%
#combing the temp data
#same station order as above
temp_all = pd.concat([df_1["TempC"],df_2["TempC"], df_3["TempC"], df_4["TempC"]])

# %% [markdown]
# So at this point we should have nice concatenated arrays or dataframe columns for depth, latitude, and whichever CTD variable you choose
#
# To plot our transect contour, let's first reassign the names depth, latitude, and CTD variable so we don't get confused
#
# Execute this code below:
# ```
#     x = lat_all
#     y = depth_all
#     z = temp_all <--- put in the concatenated CTD variable you chose
# ```

# %%
x = lat_all
y = depth_all
z = temp_all

# %% [markdown]
# Now we have our x, y, and z in order, we can plot the transect contour using this code:
#
# ```
# colorby = z #color by the variable you chose
# colormap = '' #pick a colormap scheme
# plt.figure()
# plt.scatter(x,y,z, c=colorby, cmap=colormap, alpha=1.0)
# plt.gca().invert_yaxis()
# plt.gca().invert_xaxis() # invert lats so we get a plot that is oriented N-->
# plt.colorbar()
# ```
#
# Remember from our first Python lab:
# ```
# x = data position
# y = data position
# c = sequence of numbers to be mapped to colors
# cmap = colormap
# alpha = transparency, where opaque==1
# ```
#
# And you can change pick a different colormap scheme from here: https://matplotlib.org/stable/tutorials/colors/colormaps.html

# %%
colorby = z #color by the variable you chose
colormap = 'jet_r' #pick a colormap scheme
plt.figure() #make the plot
plt.scatter(x,y,z, c=colorby, cmap=colormap, alpha=1.0) #scatter arguments as above
plt.gca().invert_yaxis() #invert depth so we see surface at top
plt.gca().invert_xaxis() # invert lats so we get a plot that is oriented N-->S
plt.colorbar()

# %% [markdown]
# Now add some axis labels and a title to your plot

# %%
colorby = z #color by the variable you chose
colormap = 'jet_r' #pick a colormap scheme
plt.figure() #make the plot
plt.scatter(x,y,z, c=colorby, cmap=colormap, alpha=1.0) #scatter arguments as above
plt.gca().invert_yaxis() #invert depth so we see surface at top
plt.gca().invert_xaxis() # invert lats so we get a plot that is oriented N-->S
plt.colorbar(label = 'Temperature (C)')

plt.ylabel("Depth(m)") #setting y label
plt.xlabel("Latitude") #setting x label
plt.title("Temperature across Transect") #title!!!
plt.savefig("Assignment_5_Transect_temps.pdf") #this is the figure I chose to save as a pdf

# %% [markdown]
# ### Exercise 8: Describe the plot
#
# How does the variable change from inshore to offshore?
#
# Do the values at the surface change from inshore to offshore?
#
# What do you think is the main driver of the pattern you see?

# %% [markdown]
# There isn't huge variablility from inshore to offshore in the temperature. Overall, the temperature is slightly lower at the surface, but there is a small difference. Offshore temps are slightly cooler than inshore temps.

# %% [markdown]
# ### Exercise 9: Create 2 more CTD profile transects
#
#
# Now let's examine the transect of 2 more CTD profiles.
# Pick 2 other CTD variables and plot them in the same way you did above.
#
#
# Change the colormap scheme for each of the plots.
#
#
# Remember, you will have to concatenate the new variables for your new zs, but you can use the same x and y as we already defined.
#
#
# After you complete each plot, describe the patterns you see in the profiles as they move from the bay to offshore.
#
#
# Add as many cells below as you need to complete these two plots.

# %%
#I forgot what the column names are so I'll take another look
df_1.head()
# Out:
#    Scan  Depth  Salinity    TempC  O2Percent      O2     pH   SpecCond  \
# 0   584  0.495   30.5963  29.4735     89.623  5.7750  7.846  47060.013
# 1   585  0.495   30.5995  29.4695     89.637  5.7762  7.846  47064.305
# 2   586  0.533   30.6189  29.4592     89.653  5.7776  7.846  47090.903
# 3   587  0.590   30.6339  29.4547     89.687  5.7797  7.846  47111.509
# 4   588  0.667   30.6351  29.4578     89.741  5.7828  7.846  47113.231
#
#    BeamAtt  BeamTrans    Density   Cond           PAR  FlCDOM  FlWETSTAR
# 0   0.8478    91.8716  1018.6072  51277  1.000000e-12  1.1068          0
# 1   0.8478    91.8716  1018.6109  51278  1.000000e-12  1.0763          0
# 2   0.8478    91.8716  1018.6290  51297  1.000000e-12  0.5573          0
# 3   0.8478    91.8716  1018.6420  51316  1.000000e-12  0.5573          0
# 4   0.8478    91.8716  1018.6422  51320  1.000000e-12  0.5268          0

# %%
#start by doing a CTD transect for salninity instead of temperature
#combine the salinity data in the correct station order
sal_all = pd.concat([df_1["Salinity"],df_2["Salinity"], df_3["Salinity"], df_4["Salinity"]]) 
#remember that the lat and depth arrays have already been defined
#these are the variables we will be plotting, redefined just in case
x = lat_all
y = depth_all
z2= sal_all #new variable name

colorby = z2 #color by the variable you chose
colormap = 'cool' #pick a colormap scheme
plt.figure() #make the plot
plt.scatter(x,y,z2, c=colorby, cmap=colormap, alpha=1.0) #scatter arguments as above
plt.gca().invert_yaxis() #invert depth so we see surface at top
plt.gca().invert_xaxis() # invert lats so we get a plot that is oriented N-->S
plt.colorbar(label = 'Salinity (psu)')

plt.ylabel("Depth(m)") #setting y label
plt.xlabel("Latitude") #setting x label
plt.title("Salinity across Transect") #title!!!
# Out:
# Text(0.5, 1.0, 'Salinity across Transect')

# %% [markdown]
# The salinity is always lower at the surface than at depth. There does not seem to be huge differences moving across the transect, which is odd, as we moved away from the mouth of Mobile Bay on the transect. However, the most northern station does appear to ahve a lower surface and range than the other stations.

# %%
#now I'll do a CTD transect for O2
#combine the oxygen data in the correct station order
O2_all = pd.concat([df_1["O2"],df_2["O2"], df_3["O2"], df_4["O2"]]) 
#remember that the lat and depth arrays have already been defined
#these are the variables we will be plotting, redefined just in case
x = lat_all
y = depth_all
z3= O2_all #new variable name

colorby = z3 #color by the variable you chose
colormap = 'hot' #pick a colormap scheme
plt.figure() #make the plot
plt.scatter(x,y,z3, c=colorby, cmap=colormap, alpha=1.0) #scatter arguments as above
plt.gca().invert_yaxis() #invert depth so we see surface at top
plt.gca().invert_xaxis() # invert lats so we get a plot that is oriented N-->S
plt.colorbar(label = 'O2 (mg/L)')

plt.ylabel("Depth(m)") #setting y label
plt.xlabel("Latitude") #setting x label
plt.title("Oxygen across Transect") #title!!!
# Out:
# Text(0.5, 1.0, 'Oxygen across Transect')

# %% [markdown]
# There is considerable more oxygen at the mouth of Mobile Bay than farther south. There is a larger range at stations 2&3 than the other stations, with lowest concentrations at depth.

# %% [markdown]
# #### That's all!!!
#
# Many of the above answers depend heavily on which variables you chose to define/plot, so please keep that in mind as you're looking over your grades.
